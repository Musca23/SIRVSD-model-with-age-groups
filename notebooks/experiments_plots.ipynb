# %% [markdown]
# ## Experimental results with different configurations

# %% [markdown]
# ### Case Study: COVID-19 pandemic
# Run following experiments with these fixed initial conditions and parameters:
# - $\textit{S(0)}$ = 99% (Susceptible)
# - $\textit{I(0)}$ = 1% (Infectious)
# - $\textit{R(0)}$ = 0% (Recovered)
# - $\textit{V(0)}$ = 0% (Vaccinated)
# - $\textit{D(0)}$ = 0% (Deceased)
# - $\gamma$ = 1/15 (Recovery Coefficient)
# - $\mu$ = [0.00009, 0.00005, 0.00688, 0.15987] (Mortality Coefficient)
# - $\phi$ = 1/180 (Transfer Rate for loss of immunity from recovered)
# - $\rho$ = 1/270 (Transfer Rate for loss of immunity from vaccinated)
# - $ \beta = \begin{bmatrix}
#         0.05 & 0.01 & 0.04 & 0.008\\
#         0.01 & 0.09 & 0.08 & 0.008 \\
#         0.04 & 0.08 & 0.1 & 0.02 \\
#         0.008 & 0.008 & 0.02 & 0.03
# \end{bmatrix}$ (Infection Coefficient)

# %% [markdown]
# ### No vaccination and all compartments for each age group

# %% [markdown]
# #### Mortality comparison for each age group

# %% [markdown]
# #### Infections comparison for each age group

# %% [markdown]
# ### Vaccination strategy for age groups in ascending order

# %% [markdown]
# - $\eta$ = [0.01, 0.01, 0.01, 0.01] (Vaccination Rate)
# - START_VACCINATION_GROUP = [0, 30, 60, 90] (starting day of the vaccination period)

# %% [markdown]
# #### Mortality comparison for each age group

# %% [markdown]
# #### Infections comparison for each age group

# %% [markdown]
# ### Vaccination strategy for age groups in descending order

# %% [markdown]
# - $\eta$ = [0.01, 0.01, 0.01, 0.01] (Vaccination Rate)
# - START_VACCINATION_GROUP = [90, 60, 30, 0] (starting day of the vaccination period)

# %% [markdown]
# #### Mortality comparison for each age group

# %% [markdown]
# #### Infections comparison for each age group

# %% [markdown]
# ### Vaccination strategy for age groups at the same time

# %% [markdown]
# - $\eta$ = [0.0025, 0.0025, 0.0025, 0.0025] (Vaccination Rate)
# - START_VACCINATION_GROUP = [0, 0, 0, 0] (starting day of the vaccination period)

# %% [markdown]
# #### Mortality comparison for each age group

# %% [markdown]
# #### Infections comparison for each age group

# %%
# %run ./src/main.py

# %% [markdown]
# ## Vaccination strategy for the whole population

# %% [markdown]
# ### No vaccination
# ![endemic_state.jpg](attachment:endemic_state.jpg)

# %% [markdown]
# #### 'Zero Infections Day'
# ![zero_day_infection.jpg](attachment:zero_day_infection.jpg)

# %% [markdown]
# ### Ascending Order

# %% [markdown]
# - $\eta$ = [0.01, 0.01, 0.01, 0.01] (Vaccination Rate)
# - START_VACCINATION_GROUP = [0, 30, 60, 90] (starting day of the vaccination period)
# ![eradication_disease.jpg](attachment:eradication_disease.jpg)

# %% [markdown]
# #### 'Zero Infections Day'
# ![zero_day_infection.jpg](attachment:zero_day_infection.jpg)

# %% [markdown]
# #### 'Zero Deaths Day'
# ![zero_day_deaths.jpg](attachment:zero_day_deaths.jpg)

# %% [markdown]
# ### Descending Order

# %% [markdown]
# - $\eta$ = [0.01, 0.01, 0.01, 0.01] (Vaccination Rate)
# - START_VACCINATION_GROUP = [90, 60, 30, 0] (starting day of the vaccination period)
# ![eradication_disease.jpg](attachment:eradication_disease.jpg)

# %% [markdown]
# #### 'Zero Infections Day'
# ![zero_day_infection.jpg](attachment:zero_day_infection.jpg)

# %% [markdown]
# #### 'Zero Deaths Day'
# ![zero_day_deaths.jpg](attachment:zero_day_deaths.jpg)

# %% [markdown]
# ### Same time

# %% [markdown]
# - $\eta$ = [0.0025, 0.0025, 0.0025, 0.0025] (Vaccination Rate)
# - START_VACCINATION_GROUP = [0, 0, 0, 0] (starting day of the vaccination period)
# ![endemic_state.jpg](attachment:endemic_state.jpg)

# %% [markdown]
# #### 'Zero Infections Day'
# ![zero_day_infection.jpg](attachment:zero_day_infection.jpg)

# %% [markdown]
# ### Mortality comparison
# ![bar_chart_deaths_comparison.jpeg](attachment:bar_chart_deaths_comparison.jpeg)

# %% [markdown]
# ### Infection comparison

# %% [markdown]
# ### Recovery comparison

# %%
# %run ./src/main.py
